# %% [markdown]
# <a href="https://colab.research.google.com/github/rosnaaidiploma-web/Rosnaelizabeth/blob/main/Bike_Prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
df = pd.read_csv("/content/Bike Prices.csv")
df
# Out:
#       Brand                      Model  Selling_Price  Year Seller_Type  \
# 0       TVS                 TVS XL 100          30000  2017  Individual
# 1     Bajaj              Bajaj  ct 100          18000  2017  Individual
# 2        Yo                   Yo Style          20000  2011  Individual
# 3     Bajaj         Bajaj Discover 100          25000  2010  Individual
# 4     Bajaj         Bajaj Discover 100          24999  2012  Individual
# ...     ...                        ...            ...   ...         ...
# 1056  Royal  Royal Enfield Electra 5 S          90000  2012  Individual
# 1057   Hero            Hero Honda Hunk          20000  2010  Individual
# 1058  Bajaj     Bajaj Pulsar 220 DTS-i          60000  2014  Individual
# 1059   Hero     Hero Honda CBZ extreme          40000  2009  Individual
# 1060   Hero     Hero Honda CBZ extreme          35000  2012  Individual
#
#           Owner  KM_Driven  Ex_Showroom_Price
# 0     1st owner       8000            30490.0
# ...

# %% [markdown]
# ***Data Exploration***

# %%
df.head(7)
# Out:
#    Brand               Model  Selling_Price  Year Seller_Type      Owner  \
# 0    TVS          TVS XL 100          30000  2017  Individual  1st owner
# 1  Bajaj       Bajaj  ct 100          18000  2017  Individual  1st owner
# 2     Yo            Yo Style          20000  2011  Individual  1st owner
# 3  Bajaj  Bajaj Discover 100          25000  2010  Individual  1st owner
# 4  Bajaj  Bajaj Discover 100          24999  2012  Individual  2nd owner
# 5  Bajaj  Bajaj Discover 100          20000  2012  Individual  1st owner
# 6  Bajaj  Bajaj Discover 100          30000  2011  Individual  1st owner
#
#    KM_Driven  Ex_Showroom_Price
# 0       8000            30490.0
# 1      35000            32000.0
# 2      10000            37675.0
# 3      43000            42859.0
# 4      35000            42859.0
# 5      85000            42859.0
# 6      45000            42859.0

# %%
df.tail(25)
# Out:
#       Brand                         Model  Selling_Price  Year Seller_Type  \
# 1036   Hero      Hero Honda Splendor Plus          20000  2004  Individual
# 1037   Hero      Hero Honda Splendor Plus          20000  2010  Individual
# 1038   Hero           Hero Super Splendor          30000  2011  Individual
# 1039   Hero           Hero Super Splendor          40000  2017  Individual
# 1040  Honda                   Honda Shine          40000  2011  Individual
# 1041   Hero               Hero Honda Hunk          45000  2013  Individual
# 1042  Bajaj              Bajaj Pulsar 150          70000  2017  Individual
# 1043   Hero      Hero Honda Splendor Plus          25000  2012  Individual
# 1044   Hero                  Hero CD Dawn          35000  2014  Individual
# 1045   Hero          Hero Honda CD Deluxe          25500  2012  Individual
# 1046   Hero               Hero Honda Hunk          35000  2010  Individual
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Brand              1061 non-null   object
#  1   Model              1061 non-null   object
#  2   Selling_Price      1061 non-null   int64
#  3   Year               1061 non-null   int64
#  4   Seller_Type        1061 non-null   object
#  5   Owner              1061 non-null   object
#  6   KM_Driven          1061 non-null   int64
#  7   Ex_Showroom_Price  626 non-null    float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 66.4+ KB

# %%
df.describe()
# Out:
#        Selling_Price         Year      KM_Driven  Ex_Showroom_Price
# count    1061.000000  1061.000000    1061.000000       6.260000e+02
# mean    59638.151744  2013.867107   34359.833176       8.795871e+04
# std     56304.291973     4.301191   51623.152702       7.749659e+04
# min      5000.000000  1988.000000     350.000000       3.049000e+04
# 25%     28000.000000  2011.000000   13500.000000       5.485200e+04
# 50%     45000.000000  2015.000000   25000.000000       7.275250e+04
# 75%     70000.000000  2017.000000   43000.000000       8.703150e+04
# max    760000.000000  2020.000000  880000.000000       1.278000e+06

# %%
df.isnull().sum()
# Out:
# Brand                  0
# Model                  0
# Selling_Price          0
# Year                   0
# Seller_Type            0
# Owner                  0
# KM_Driven              0
# Ex_Showroom_Price    435
# dtype: int64

# %%
df['Brand'].value_counts()
# Out:
# Brand
# Bajaj       260
# Hero        232
# Honda       204
# Royal       109
# Yamaha      102
# TVS          69
# Suzuki       30
# KTM          24
# Mahindra      6
# Kawasaki      4
# Vespa         4
# UM            3
# Jawa          3
# Activa        3
# Harley        2
# Aprilia       2
# Yo            1
# Benelli       1
# Hyosung       1
# BMW           1
# Name: count, dtype: int64

# %% [markdown]
# ***data visualization***

# %%
plt.scatter(df['Seller_Type'],df['Year'],edgecolors='red',facecolors='white')
plt.title("sellertype_year")
plt.xlabel('Seller_types')
plt.ylabel('Year')

plt.show()

# %%
plt.plot(df['Brand'],animated=0)
plt.plot(df['Owner'],animated=1)

plt.title("lineplot")
plt.show()

# %%
plt.plot(df['Brand'], label='Brand')
line2, = plt.plot(df['Owner'], label='Owner')


line2.set_animated(True)
plt.title("Line Plot")
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt


df_limited = df[['Year', 'Model']].head(5)

plt.figure(figsize=(10, 6))
bars = plt.bar(df_limited['Year'], df_limited['Model'],
               color='skyblue',
               edgecolor='navy',
               linewidth=2,
               alpha=0.8)
plt.title("Year vs Model (Top 5)", fontsize=14, fontweight='bold')
plt.xlabel('Year', fontsize=12)
plt.ylabel('Model', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', alpha=0.3)



plt.tight_layout()
plt.show()

# %%
# x expanded (correct)
plt.hist(df['KM_Driven'])

plt.title("Histogram")

plt.show()

# %%
df_limited = df[['Model', 'Selling_Price', 'Year']].head(5)

plt.figure(figsize=(10, 6))
sns.barplot(x='Model', y='Selling_Price', data=df_limited, hue='Year',
            palette='Set2',
            dodge=True,
            edgecolor='black',
            linewidth=1)

plt.title("Selling Price by Model (Top 5)", fontsize=14, fontweight='bold')
plt.xlabel('Selling Price', fontsize=5)
plt.ylabel('Model', fontsize=3)
plt.legend(title='Year')
plt.tight_layout()
plt.show()

# %% [markdown]
# ***Handling Missing Values***

# %%
df.isnull().sum()
# Out:
# Brand                  0
# Model                  0
# Selling_Price          0
# Year                   0
# Seller_Type            0
# Owner                  0
# KM_Driven              0
# Ex_Showroom_Price    435
# dtype: int64

# %%
data =df
data
# Out:
#       Brand                      Model  Selling_Price  Year Seller_Type  \
# 0       TVS                 TVS XL 100          30000  2017  Individual
# 1     Bajaj              Bajaj  ct 100          18000  2017  Individual
# 2        Yo                   Yo Style          20000  2011  Individual
# 3     Bajaj         Bajaj Discover 100          25000  2010  Individual
# 4     Bajaj         Bajaj Discover 100          24999  2012  Individual
# ...     ...                        ...            ...   ...         ...
# 1056  Royal  Royal Enfield Electra 5 S          90000  2012  Individual
# 1057   Hero            Hero Honda Hunk          20000  2010  Individual
# 1058  Bajaj     Bajaj Pulsar 220 DTS-i          60000  2014  Individual
# 1059   Hero     Hero Honda CBZ extreme          40000  2009  Individual
# 1060   Hero     Hero Honda CBZ extreme          35000  2012  Individual
#
#           Owner  KM_Driven  Ex_Showroom_Price
# 0     1st owner       8000            30490.0
# ...

# %%
data=data.fillna(10000)
data.bfill()

data.head(4)
# Out:
#    Brand               Model  Selling_Price  Year Seller_Type      Owner  \
# 0    TVS          TVS XL 100          30000  2017  Individual  1st owner
# 1  Bajaj       Bajaj  ct 100          18000  2017  Individual  1st owner
# 2     Yo            Yo Style          20000  2011  Individual  1st owner
# 3  Bajaj  Bajaj Discover 100          25000  2010  Individual  1st owner
#
#    KM_Driven  Ex_Showroom_Price
# 0       8000            30490.0
# 1      35000            32000.0
# 2      10000            37675.0
# 3      43000            42859.0

# %%
data.bfill()
data.tail(10)
# Out:
#       Brand                      Model  Selling_Price  Year Seller_Type  \
# 1051  Honda                 Honda Livo          45000  2017  Individual
# 1052   Hero            Hero Honda Hunk          40000  2010  Individual
# 1053   Hero             Hero HF Deluxe          35000  2018  Individual
# 1054  Bajaj                Bajaj Boxer          15000  2004  Individual
# 1055  Royal  Royal Enfield Electra 5 S          99000  2012  Individual
# 1056  Royal  Royal Enfield Electra 5 S          90000  2012  Individual
# 1057   Hero            Hero Honda Hunk          20000  2010  Individual
# 1058  Bajaj     Bajaj Pulsar 220 DTS-i          60000  2014  Individual
# 1059   Hero     Hero Honda CBZ extreme          40000  2009  Individual
# 1060   Hero     Hero Honda CBZ extreme          35000  2012  Individual
#
#           Owner  KM_Driven  Ex_Showroom_Price
# 1051  1st owner      30000            10000.0
# 1052  1st owner      41000            10000.0
# ...

# %%
sns.histplot(data.Selling_Price)
# Out:
# <Axes: xlabel='Selling_Price', ylabel='Count'>

# %%
data_dropped = data.dropna()

# %%
data
# Out:
#       Brand                      Model  Selling_Price  Year Seller_Type  \
# 0       TVS                 TVS XL 100          30000  2017  Individual
# 1     Bajaj              Bajaj  ct 100          18000  2017  Individual
# 2        Yo                   Yo Style          20000  2011  Individual
# 3     Bajaj         Bajaj Discover 100          25000  2010  Individual
# 4     Bajaj         Bajaj Discover 100          24999  2012  Individual
# ...     ...                        ...            ...   ...         ...
# 1056  Royal  Royal Enfield Electra 5 S          90000  2012  Individual
# 1057   Hero            Hero Honda Hunk          20000  2010  Individual
# 1058  Bajaj     Bajaj Pulsar 220 DTS-i          60000  2014  Individual
# 1059   Hero     Hero Honda CBZ extreme          40000  2009  Individual
# 1060   Hero     Hero Honda CBZ extreme          35000  2012  Individual
#
#           Owner  KM_Driven  Ex_Showroom_Price
# 0     1st owner       8000            30490.0
# ...

# %%
data.isnull().sum()
# Out:
# Brand                0
# Model                0
# Selling_Price        0
# Year                 0
# Seller_Type          0
# Owner                0
# KM_Driven            0
# Ex_Showroom_Price    0
# dtype: int64

# %%
data['Selling_Price'].fillna(data['Selling_Price'].median(),inplace=True)
data
# Out:
# /tmp/ipython-input-1508911914.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Selling_Price'].fillna(data['Selling_Price'].median(),inplace=True)
#       Brand                      Model  Selling_Price  Year Seller_Type  \
# 0       TVS                 TVS XL 100          30000  2017  Individual
# 1     Bajaj              Bajaj  ct 100          18000  2017  Individual
# 2        Yo                   Yo Style          20000  2011  Individual
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Brand              1061 non-null   object
#  1   Model              1061 non-null   object
#  2   Selling_Price      1061 non-null   int64
#  3   Year               1061 non-null   int64
#  4   Seller_Type        1061 non-null   object
#  5   Owner              1061 non-null   object
#  6   KM_Driven          1061 non-null   int64
#  7   Ex_Showroom_Price  1061 non-null   float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 66.4+ KB

# %% [markdown]
# ***data preprocessing***

# %%
q1, q3 = np.percentile(data['KM_Driven'], [25,75])
iqr = q3 - q1

print(iqr)
# Out:
# 30000.0

# %%
lower = q1 - 1.5*iqr
upper = q3 + 1.5*iqr

print(f"LOWER : {lower} \nUpper : {upper} \n ")
# Out:
# LOWER : -30000.0
# Upper : 90000.0

# %%
data.describe()
# Out:
#        Selling_Price         Year      KM_Driven  Ex_Showroom_Price
# count     974.000000   974.000000     974.000000         582.000000
# mean    47702.339836  2013.555441   36562.920945       75485.054983
# std     27879.645378     4.260831   53261.151122       31008.207743
# min      5000.000000  1988.000000     380.000000       30490.000000
# 25%     25000.000000  2011.000000   15000.000000       54605.000000
# 50%     40000.000000  2014.000000   27185.000000       67200.500000
# 75%     60000.000000  2017.000000   45000.000000       84751.000000
# max    130000.000000  2019.000000  880000.000000      317934.000000

# %%
d = data[(data['KM_Driven'] >= lower) & (data['KM_Driven'] <= upper)]
d
# Out:
#       Brand                      Model  Selling_Price  Year Seller_Type  \
# 0       TVS                 TVS XL 100          30000  2017  Individual
# 1     Bajaj              Bajaj  ct 100          18000  2017  Individual
# 2        Yo                   Yo Style          20000  2011  Individual
# 3     Bajaj         Bajaj Discover 100          25000  2010  Individual
# 4     Bajaj         Bajaj Discover 100          24999  2012  Individual
# ...     ...                        ...            ...   ...         ...
# 1056  Royal  Royal Enfield Electra 5 S          90000  2012  Individual
# 1057   Hero            Hero Honda Hunk          20000  2010  Individual
# 1058  Bajaj     Bajaj Pulsar 220 DTS-i          60000  2014  Individual
# 1059   Hero     Hero Honda CBZ extreme          40000  2009  Individual
# 1060   Hero     Hero Honda CBZ extreme          35000  2012  Individual
#
#           Owner  KM_Driven  Ex_Showroom_Price
# 0     1st owner       8000            30490.0
# ...

# %%
sns.boxplot(data['KM_Driven'])

plt.show()

# %%
q1, q3 = np.percentile(data['Selling_Price'], [25,75])
iqr = q3 - q1

print(iqr)
# Out:
# 33000.0

# %%
lower = q1 - 1.5*iqr
upper = q3 + 1.5*iqr

print(f"LOWER : {lower} \n Upper : {upper} \n ")
# Out:
# LOWER : -22500.0
#  Upper : 109500.0

# %%
data.isnull().sum()
# Out:
# Brand                  0
# Model                  0
# Selling_Price          0
# Year                   0
# Seller_Type            0
# Owner                  0
# KM_Driven              0
# Ex_Showroom_Price    375
# dtype: int64

# %%
data['Ex_Showroom_Price'].fillna(data['Ex_Showroom_Price'].median(),inplace=True)
data
# Out:
# /tmp/ipython-input-3436962544.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Ex_Showroom_Price'].fillna(data['Ex_Showroom_Price'].median(),inplace=True)
# /tmp/ipython-input-3436962544.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
data.isnull().sum()
# Out:
# Brand                0
# Model                0
# Selling_Price        0
# Year                 0
# Seller_Type          0
# Owner                0
# KM_Driven            0
# Ex_Showroom_Price    0
# dtype: int64

# %%
d = data[(data['Selling_Price'] >= lower) & (data['Selling_Price'] <= upper)]
d
# Out:
#       Brand                      Model  Selling_Price  Year Seller_Type  \
# 0       TVS                 TVS XL 100          30000  2017  Individual
# 1     Bajaj              Bajaj  ct 100          18000  2017  Individual
# 2        Yo                   Yo Style          20000  2011  Individual
# 3     Bajaj         Bajaj Discover 100          25000  2010  Individual
# 4     Bajaj         Bajaj Discover 100          24999  2012  Individual
# ...     ...                        ...            ...   ...         ...
# 1056  Royal  Royal Enfield Electra 5 S          90000  2012  Individual
# 1057   Hero            Hero Honda Hunk          20000  2010  Individual
# 1058  Bajaj     Bajaj Pulsar 220 DTS-i          60000  2014  Individual
# 1059   Hero     Hero Honda CBZ extreme          40000  2009  Individual
# 1060   Hero     Hero Honda CBZ extreme          35000  2012  Individual
#
#           Owner  KM_Driven  Ex_Showroom_Price
# 0     1st owner       8000            30490.0
# ...

# %%
sns.boxplot(df['Selling_Price'])

plt.show()

# %%
q1, q3 = np.percentile(data['Ex_Showroom_Price'], [25,75])
iqr = q3 - q1

print(iqr)
# Out:
# 13902.0

# %%
da = data[(data['Ex_Showroom_Price'] >= lower) & (data['Ex_Showroom_Price'] <= upper)]
da
# Out:
#       Brand                      Model  Selling_Price  Year Seller_Type  \
# 0       TVS                 TVS XL 100          30000  2017  Individual
# 1     Bajaj              Bajaj  ct 100          18000  2017  Individual
# 2        Yo                   Yo Style          20000  2011  Individual
# 3     Bajaj         Bajaj Discover 100          25000  2010  Individual
# 4     Bajaj         Bajaj Discover 100          24999  2012  Individual
# ...     ...                        ...            ...   ...         ...
# 1056  Royal  Royal Enfield Electra 5 S          90000  2012  Individual
# 1057   Hero            Hero Honda Hunk          20000  2010  Individual
# 1058  Bajaj     Bajaj Pulsar 220 DTS-i          60000  2014  Individual
# 1059   Hero     Hero Honda CBZ extreme          40000  2009  Individual
# 1060   Hero     Hero Honda CBZ extreme          35000  2012  Individual
#
#           Owner  KM_Driven  Ex_Showroom_Price
# 0     1st owner       8000            30490.0
# ...

# %%
sns.boxplot(da['Ex_Showroom_Price'])

plt.show()

# %%
X = data.drop(columns=['Selling_Price'])
y = data['Selling_Price']

# X - input features

# y - output/target value


display(X)
display(y)
# Out:
#       Brand                      Model  Year Seller_Type      Owner  \
# 0       TVS                 TVS XL 100  2017  Individual  1st owner
# 1     Bajaj              Bajaj  ct 100  2017  Individual  1st owner
# 2        Yo                   Yo Style  2011  Individual  1st owner
# 3     Bajaj         Bajaj Discover 100  2010  Individual  1st owner
# 4     Bajaj         Bajaj Discover 100  2012  Individual  2nd owner
# ...     ...                        ...   ...         ...        ...
# 1056  Royal  Royal Enfield Electra 5 S  2012  Individual  1st owner
# 1057   Hero            Hero Honda Hunk  2010  Individual  1st owner
# 1058  Bajaj     Bajaj Pulsar 220 DTS-i  2014  Individual  1st owner
# 1059   Hero     Hero Honda CBZ extreme  2009  Individual  1st owner
# 1060   Hero     Hero Honda CBZ extreme  2012  Individual  1st owner
#
#       KM_Driven  Ex_Showroom_Price
# 0          8000            30490.0
# 1         35000            32000.0
# 2         10000            37675.0
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
numerical_cols = X.select_dtypes(include=['int64', 'float64']).columns
X_norm = scaler.fit_transform(X[numerical_cols])

normal_df = pd.DataFrame(X_norm, columns=numerical_cols)
display(normal_df)
# Out:
#          Year  KM_Driven  Ex_Showroom_Price
# 0    0.935484   0.085026           0.000000
# 1    0.935484   0.386298           0.005253
# 2    0.741935   0.107342           0.024996
# 3    0.709677   0.475563           0.043031
# 4    0.774194   0.386298           0.043031
# ..        ...        ...                ...
# 933  0.774194   0.442089           0.127667
# 934  0.709677   0.185450           0.127667
# 935  0.838710   0.174291           0.127667
# 936  0.677419   0.553671           0.127667
# 937  0.774194   0.665253           0.127667
#
# [938 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
numerical_cols = X.select_dtypes(include=['int64', 'float64']).columns
X_std = scaler.fit_transform(X[numerical_cols])
print(X_std)
# Out:
# [[ 0.78679655 -1.1267863  -1.69950039]
#  [ 0.78679655  0.24879573 -1.63813268]
#  [-0.64023889 -1.02489134 -1.40749573]
#  ...
#  [ 0.07327883 -0.71920644 -0.20810236]
#  [-1.11591737  1.01300797 -0.20810236]
#  [-0.40239965  1.5224828  -0.20810236]]

# %%
Standard_df=pd.DataFrame(X_std)
Standard_df.describe()
# Out:
#                   0             1           2
# count  9.380000e+02  9.380000e+02  938.000000
# mean   9.574904e-15 -6.438820e-17    0.000000
# std    1.000533e+00  1.000533e+00    1.000533
# min   -6.110541e+00 -1.515006e+00   -1.699500
# 25%   -6.402389e-01 -7.701539e-01   -0.435163
# 50%    3.111181e-01 -2.097316e-01   -0.208102
# 75%    7.867965e-01  6.054281e-01    0.129826
# max    1.262475e+00  3.050907e+00    9.982474
