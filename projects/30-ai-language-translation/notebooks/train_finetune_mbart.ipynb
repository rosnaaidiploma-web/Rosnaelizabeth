# %% [markdown]
# # Fine-tune mBART (example)
#
# This is a short tutorial notebook showing the high-level steps to fine-tune a seq2seq model using the Hugging Face Transformers library. Use the `train.py` script for runnable training in non-notebook environments.

# %%
# Example: load tokenizer and model
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
model_name = 'facebook/mbart-large-50-many-to-many-mmt'
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
print('Loaded', model_name)
